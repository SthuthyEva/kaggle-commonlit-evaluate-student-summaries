# %%
from omegaconf import OmegaConf
from model import *
from transformers import AutoModelForSequenceClassification
config = OmegaConf.load("config_l.yaml")

# %%
config.model= 'microsoft/deberta-v3-large'

model = Model(config)
# model = AutoModelForSequenceClassification.from_pretrained(config.model)

# config.train.num_freeze = 386

for idx, (n, p) in enumerate(model.named_parameters()):
        if (idx > -1) & (idx <= config.train.num_freeze):
#         if (idx < 3):
            p.requires_grad = False

pytorch_total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(pytorch_total_params)

for idx, (n, p) in enumerate(model.named_parameters()):
    print(f"{idx} - {n} - {p.requires_grad}, {p.shape}")
# Out:
# 2023-10-10 20:17:25.908 | INFO     | model:__init__:101 - Adding Mean Pooling layer
# 302839810
# 0 - model.embeddings.word_embeddings.weight - False, torch.Size([128100, 1024])
# 1 - model.embeddings.LayerNorm.weight - True, torch.Size([1024])
# 2 - model.embeddings.LayerNorm.bias - True, torch.Size([1024])
# 3 - model.encoder.layer.0.attention.self.query_proj.weight - True, torch.Size([1024, 1024])
# 4 - model.encoder.layer.0.attention.self.query_proj.bias - True, torch.Size([1024])
# 5 - model.encoder.layer.0.attention.self.key_proj.weight - True, torch.Size([1024, 1024])
# 6 - model.encoder.layer.0.attention.self.key_proj.bias - True, torch.Size([1024])
# 7 - model.encoder.layer.0.attention.self.value_proj.weight - True, torch.Size([1024, 1024])
# 8 - model.encoder.layer.0.attention.self.value_proj.bias - True, torch.Size([1024])
# 9 - model.encoder.layer.0.attention.output.dense.weight - True, torch.Size([1024, 1024])
# ...

# %%
# b_0 = 85452290
# l_194 = 151683074
# l_370 = 13124610
#         131702786

# l_0 = 434014210
# l_3 = 302837762
l_3_386=132753410

# %%
import re
s = "https://rdfdfg.com is here"
t = re.sub('https?://\S+|www\.\S+', ' social medium ', s)
t
# Out:
# ' social medium  is here'

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/sthueva/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True
